# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhigaikwad/Web-Surfers/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec

# %%
import pandas as pd

data = pd.read_csv(
    "/creditcard.csv",
    on_bad_lines="skip"
)

print(data.head())
print(data.shape)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(data.describe())
# Out:
#                 Time             V1             V2             V3  \
# count  266900.000000  266900.000000  266900.000000  266900.000000
# mean    99812.123507       0.014796      -0.013621      -0.048036
# std     44759.549056       1.956472       1.654926       1.477377
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     60395.000000      -0.918915      -0.614163      -0.958794
# 50%     95448.000000       0.022464       0.058285       0.119945
# 75%    141164.250000       1.359849       0.802381       0.977045
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  266900.000000  266900.000000  266900.000000  266900.000000
# mean       -0.021297       0.013924      -0.006385       0.013737
# std         1.410837       1.373977       1.332162       1.227033
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
fraud = data[data['Class'] == 1]
valid = data[data['Class'] == 0]
outlierFraction = len(fraud)/float(len(valid))
print(outlierFraction)
print('Fraud Cases: {}'.format(len(data[data['Class'] == 1])))
print('Valid Transactions: {}'.format(len(data[data['Class'] == 0])))
# Out:
# 0.0015310085518835533
# Fraud Cases: 408
# Valid Transactions: 266491

# %%
print("Amount details of the fraudulent transaction")
fraud.Amount.describe()
# Out:
# Amount details of the fraudulent transaction
# count     408.000000
# mean      128.855980
# std       256.078383
# min         0.000000
# 25%         1.000000
# 50%        12.310000
# 75%       123.142500
# max      2125.870000
# Name: Amount, dtype: float64

# %%
print("details of valid transaction")
valid.Amount.describe()
# Out:
# details of valid transaction
# count    266491.000000
# mean         89.305045
# std         252.925137
# min           0.000000
# 25%           5.490000
# 50%          22.370000
# 75%          78.060000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
corrmat = data.corr()
fig = plt.figure(figsize = (12, 9))
sns.heatmap(corrmat, vmax = .8, square = True)
plt.show()

# %%
X = data.drop(['Class'], axis = 1)
Y = data["Class"]
print(X.shape)
print(Y.shape)

xData = X.values
yData = Y.values

from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(
        xData, yData, test_size = 0.2, random_state = 42)
# Out:
# (266900, 30)
# (266900,)

# %%
#Step 1: Check NaNs in Class
data['Class'].isna().sum()
# Out:
# np.int64(1)

# %%
#Remove rows where Class is NaN
data = data.dropna(subset=['Class'])

# %%
#Step 3: (Recommended) Ensure Class is integer
data['Class'] = data['Class'].astype(int)

# %%
#Step 4: Re-create X and Y
X = data.drop('Class', axis=1)
Y = data['Class']

xData = X.values
yData = Y.values

# %%
#Step 5: Re-split the dataset
from sklearn.model_selection import train_test_split

xTrain, xTest, yTrain, yTest = train_test_split(
    xData, yData, test_size=0.2, random_state=42
)

# %%
#Step 6: Train Random Forest
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(random_state=42)
rfc.fit(xTrain, yTrain)

yPred = rfc.predict(xTest)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-907808928.py in <cell line: 0>()
#       3
#       4 rfc = RandomForestClassifier(random_state=42)
# ----> 5 rfc.fit(xTrain, yTrain)
#       6
#       7 yPred = rfc.predict(xTest)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     485             # parallel_backend contexts set at a higher level,
#     486             # since correctness does not rely on using threads.
# --> 487             trees = Parallel(
#     488                 n_jobs=self.n_jobs,
# ...

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000, n_jobs=-1)
lr.fit(xTrain, yTrain)

yPred = lr.predict(xTest)

# %%
from google.colab import drive
drive.mount('/content/drive')
